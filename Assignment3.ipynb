# %% [markdown]
# <a href="https://colab.research.google.com/github/laurenwinslett/helloAI/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
# !git clone "https://github.com/kartoone/nn3"
# !git pull
# Out:
# Cloning into 'nn3'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 200 (delta 49), reused 29 (delta 12), pack-reused 109
# Receiving objects: 100% (200/200), 94.54 MiB | 22.73 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Updating files: 100% (110/110), done.
# Already up to date.

# %%
# %cd nn3/src
# Out:
# /content/nn3/src/nn3/src/nn3/src

# %%
from network import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[-0.92865694],
#        [ 2.27369205],
#        [ 1.74973308],
#        [-1.00505033],
#        [-0.70874084],
#        [-1.5140794 ],
#        [-1.00581006],
#        [ 2.08450387],
#        [ 0.16250001],
#        [ 1.50166973],
#        [-1.97143275],
#        [-0.0469203 ],
#        [ 0.9610975 ],
#        [-0.42477303],
#        [ 0.62188188],
#        [ 1.19510641],
#        [-0.04143458],
#        [-0.70058274],
#        [-0.12706282],
#        [-1.55472159],
#        [-0.21054107],
#        [-0.22549636],
#        [ 1.73293701],
#        [-0.25319145],
#        [-1.16862989],
#        [ 0.52704158],
#        [-0.43115478],
#        [-0.89683882],
#        [-1.31232808],
#        [-1.10365114]]), array([[-1.16245855],
#        [ 0.27575169],
#        [-1.11625999],
#        [ 0.82427249],
#        [-0.50718508],
#        [ 0.50328255],
#        [ 0.44994938],
#        [ 0.03998389],
#        [ 0.59222919],
#        [ 0.39320964]])]
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:2007: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
import numpy as np


def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti

# %%
from network import Network
import mnist_loader
import time

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
configs = [[784,15,10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], ] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
training_times = []
accuracies = []
for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:100], 30, 10, 3.0, test_data=test_data[0:100]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net)
    import matplotlib.pyplot as plt
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [784, 15, 10]
# Epoch 0: starting...training completed in 0.03s...measuring accuracy...18 / 100 in 0.0s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...29 / 100 in 0.0s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.0s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.01s...measuring accuracy...39 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.0s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...35 / 100 in 0.0s
# Epoch 8: starting...training completed in 0.06s...measuring accuracy...38 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.01s...measuring accuracy...41 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.0s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.0s
# Epoch 12: starting...training completed in 0.01s...measuring accuracy...45 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.0s
# Epoch 14: starting...training completed in 0.01s...measuring accuracy...44 / 100 in 0.0s
# Epoch 15: starting...training completed in 0.01s...measuring accuracy...44 / 100 in 0.0s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.01s...measuring accuracy...42 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.0s
# Epoch 19: starting...training completed in 0.01s...measuring accuracy...47 / 100 in 0.0s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...46 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.0s
# Epoch 23: starting...training completed in 0.01s...measuring accuracy...48 / 100 in 0.0s
# Epoch 24: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.01s...measuring accuracy...51 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...52 / 100 in 0.0s
# Epoch 28: starting...training completed in 0.01s...measuring accuracy...49 / 100 in 0.0s
# Epoch 29: starting...training completed in 0.01s...measuring accuracy...48 / 100 in 0.0s
# 0.7187204360961914
# 0.07285230133258165
# 44
# [784, 30, 10]
# Epoch 0: starting...training completed in 0.04s...measuring accuracy...18 / 100 in 0.0s
# Epoch 1: starting...training completed in 0.05s...measuring accuracy...27 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...30 / 100 in 0.0s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...33 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.03s...measuring accuracy...38 / 100 in 0.0s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.0s
# Epoch 8: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.0s
# Epoch 17: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.0s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.0s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.0s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.0s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.03s...measuring accuracy...44 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.03s...measuring accuracy...45 / 100 in 0.01s
# 0.8682091236114502
# 0.060866151141427294
# 86
# [784, 100, 10]
# Epoch 0: starting...training completed in 0.05s...measuring accuracy...17 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.04s...measuring accuracy...16 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.04s...measuring accuracy...27 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.07s...measuring accuracy...23 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.04s...measuring accuracy...25 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.05s...measuring accuracy...28 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.05s...measuring accuracy...25 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.05s...measuring accuracy...28 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.04s...measuring accuracy...29 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.04s...measuring accuracy...26 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.05s...measuring accuracy...27 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.06s...measuring accuracy...34 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.05s...measuring accuracy...36 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.08s...measuring accuracy...35 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.05s...measuring accuracy...35 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.06s...measuring accuracy...36 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.05s...measuring accuracy...35 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.04s...measuring accuracy...34 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.08s...measuring accuracy...36 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.07s...measuring accuracy...35 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.05s...measuring accuracy...36 / 100 in 0.03s
# Epoch 28: starting...training completed in 0.05s...measuring accuracy...36 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.04s...measuring accuracy...40 / 100 in 0.01s
# 1.7800827026367188
# 0.0034362158954015076
# 57
# [784, 15, 15, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...15 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...15 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...19 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...22 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.02s...measuring accuracy...24 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...33 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.03s...measuring accuracy...33 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.02s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.02s
# Epoch 15: starting...training completed in 0.03s...measuring accuracy...36 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.03s...measuring accuracy...36 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.03s...measuring accuracy...39 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.03s...measuring accuracy...40 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.04s...measuring accuracy...40 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.03s...measuring accuracy...41 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.03s...measuring accuracy...42 / 100 in 0.02s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# 0.9220504760742188
# 0.1503046954914386
# 24

# %%
print(configs)
print(training_times)
print(accuracies)
# Out:
# [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10]]
# [0.7187204360961914, 0.8682091236114502, 1.7800827026367188, 0.9220504760742188]
# [48, 45, 40, 40]

# %%
from network2 import Network
from network2 import QuadraticCost
import mnist_loader
import time
import matplotlib.pyplot as plt

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
configs = [] 
for epochs in [15, 30, 45, 100]:
  for batchsize in [5, 10, 20, 100]:
     for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0, 6.0]:
        configs.append([epochs, batchsize, learningrate])

# only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
training_data = training_data[0:100]
test_data = test_data[0:100]

training_times = []
accuracies = []  

for config in configs:
  print(config, "Single Hidden Layer plus Cross-Entropy")
  start = time.time()
  net1 = Network([784,15,10]) # cross-entropy cost
  accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
  finish = time.time()
  elapsed = finish - start
  print(elapsed)
  training_times.append(elapsed)
  ii = findTroublesomeImage(test_data[0:100], net1)
  plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
  plt.show()

  print(config, "Single Hidden Layer Plus Quadratic")
  start = time.time()
  net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
  accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
  finish = time.time()
  elapsed = finish - start
  print(elapsed)
  training_times.append(elapsed)
  ii = findTroublesomeImage(test_data[0:100], net1)
  plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
  plt.show()

  # repeat for the two layer network
  print(config, "Dual Hidden Layers Plus Cross-Entropy")
  start = time.time()
  net2 = Network([784,30,15,10])
  accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
  finish = time.time()
  elapsed = finish - start
  print(elapsed)
  training_times.append(elapsed)
  ii = findTroublesomeImage(test_data[0:100], net2)
  plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
  plt.show()

  print(config, "Dual Hidden Layers Plus Quadratic")
  start = time.time()
  net2 = Network([784,30,15, 10],cost=QuadraticCost)
  accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
  finish = time.time()
  elapsed = finish - start
  print(elapsed)
  training_times.append(elapsed)
  ii = findTroublesomeImage(test_data[0:100], net2)
  plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
  plt.show()
# Out:
# [15, 5, 0.1] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.35
# Epoch 2 training complete
# 2,0.26
# Epoch 3 training complete
# 3,0.42
# Epoch 4 training complete
# 4,0.44
# Epoch 5 training complete
# 5,0.45
# Epoch 6 training complete
# 6,0.43
# Epoch 7 training complete
# 7,0.58
# Epoch 8 training complete
# 8,0.58
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.62
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.63
# Epoch 14 training complete
# 14,0.64
# 0.35880136489868164
# 0.13601483307071982
# 11
# [15, 5, 0.1] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.13
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.23
# Epoch 5 training complete
# 5,0.23
# Epoch 6 training complete
# 6,0.22
# Epoch 7 training complete
# 7,0.21
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.21
# Epoch 10 training complete
# 10,0.23
# Epoch 11 training complete
# 11,0.23
# Epoch 12 training complete
# 12,0.23
# Epoch 13 training complete
# 13,0.24
# Epoch 14 training complete
# 14,0.23
# 0.797358512878418
# 0.14289747668549443
# 64
# [15, 5, 0.1] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.2
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.2
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.2
# Epoch 10 training complete
# 10,0.28
# Epoch 11 training complete
# 11,0.31
# Epoch 12 training complete
# 12,0.4
# Epoch 13 training complete
# 13,0.35
# Epoch 14 training complete
# 14,0.39
# 1.62044358253479
# 0.1271246584343579
# 45
# [15, 5, 0.1] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.9250161647796631
# 0.13940809963687137
# 93
# [15, 5, 0.5] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.21
# Epoch 1 training complete
# 1,0.49
# Epoch 2 training complete
# 2,0.61
# Epoch 3 training complete
# 3,0.58
# Epoch 4 training complete
# 4,0.66
# Epoch 5 training complete
# 5,0.7
# Epoch 6 training complete
# 6,0.69
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.66
# Epoch 10 training complete
# 10,0.66
# Epoch 11 training complete
# 11,0.66
# Epoch 12 training complete
# 12,0.67
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.68
# 0.3870563507080078
# 0.0637784130653678
# 84
# [15, 5, 0.5] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.21
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.34
# Epoch 4 training complete
# 4,0.28
# Epoch 5 training complete
# 5,0.43
# Epoch 6 training complete
# 6,0.37
# Epoch 7 training complete
# 7,0.53
# Epoch 8 training complete
# 8,0.55
# Epoch 9 training complete
# 9,0.54
# Epoch 10 training complete
# 10,0.5
# Epoch 11 training complete
# 11,0.56
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.63
# 0.3828611373901367
# 0.17494714391566932
# 59
# [15, 5, 0.5] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.49
# Epoch 5 training complete
# 5,0.43
# Epoch 6 training complete
# 6,0.58
# Epoch 7 training complete
# 7,0.62
# Epoch 8 training complete
# 8,0.6
# Epoch 9 training complete
# 9,0.61
# Epoch 10 training complete
# 10,0.63
# Epoch 11 training complete
# 11,0.63
# Epoch 12 training complete
# 12,0.7
# Epoch 13 training complete
# 13,0.64
# Epoch 14 training complete
# 14,0.63
# 0.619063138961792
# 0.13232391547288633
# 23
# [15, 5, 0.5] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.2
# 0.6254274845123291
# 0.1303939121217939
# 12
# [15, 5, 1.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.36
# Epoch 2 training complete
# 2,0.62
# Epoch 3 training complete
# 3,0.67
# Epoch 4 training complete
# 4,0.63
# Epoch 5 training complete
# 5,0.68
# Epoch 6 training complete
# 6,0.7
# Epoch 7 training complete
# 7,0.68
# Epoch 8 training complete
# 8,0.68
# Epoch 9 training complete
# 9,0.7
# Epoch 10 training complete
# 10,0.7
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.7
# 0.3433675765991211
# 0.04477199200599111
# 97
# [15, 5, 1.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.37
# Epoch 1 training complete
# 1,0.3
# Epoch 2 training complete
# 2,0.23
# Epoch 3 training complete
# 3,0.47
# Epoch 4 training complete
# 4,0.52
# Epoch 5 training complete
# 5,0.56
# Epoch 6 training complete
# 6,0.53
# Epoch 7 training complete
# 7,0.63
# Epoch 8 training complete
# 8,0.61
# Epoch 9 training complete
# 9,0.63
# Epoch 10 training complete
# 10,0.64
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.67
# Epoch 13 training complete
# 13,0.64
# Epoch 14 training complete
# 14,0.65
# 0.36930346488952637
# 0.19480916025380984
# 63
# [15, 5, 1.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.28
# Epoch 2 training complete
# 2,0.35
# Epoch 3 training complete
# 3,0.38
# Epoch 4 training complete
# 4,0.47
# Epoch 5 training complete
# 5,0.6
# Epoch 6 training complete
# 6,0.6
# Epoch 7 training complete
# 7,0.61
# Epoch 8 training complete
# 8,0.65
# Epoch 9 training complete
# 9,0.65
# Epoch 10 training complete
# 10,0.62
# Epoch 11 training complete
# 11,0.63
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.67
# 0.5896329879760742
# 0.03733806379354569
# 34
# [15, 5, 1.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.15
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.17
# Epoch 6 training complete
# 6,0.24
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.25
# Epoch 11 training complete
# 11,0.29
# Epoch 12 training complete
# 12,0.23
# Epoch 13 training complete
# 13,0.34
# Epoch 14 training complete
# 14,0.34
# 0.6109433174133301
# 0.13644393354575945
# 82
# [15, 5, 3.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.21
# Epoch 5 training complete
# 5,0.18
# Epoch 6 training complete
# 6,0.26
# Epoch 7 training complete
# 7,0.26
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.38
# Epoch 10 training complete
# 10,0.41
# Epoch 11 training complete
# 11,0.36
# Epoch 12 training complete
# 12,0.32
# Epoch 13 training complete
# 13,0.42
# Epoch 14 training complete
# 14,0.39
# 0.3389756679534912
# 0.16522535295581892
# 59
# [15, 5, 3.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.45
# Epoch 2 training complete
# 2,0.56
# Epoch 3 training complete
# 3,0.6
# Epoch 4 training complete
# 4,0.65
# Epoch 5 training complete
# 5,0.61
# Epoch 6 training complete
# 6,0.66
# Epoch 7 training complete
# 7,0.64
# Epoch 8 training complete
# 8,0.68
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.68
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.67
# Epoch 13 training complete
# 13,0.69
# Epoch 14 training complete
# 14,0.68
# 0.46532607078552246
# 0.14584547387410382
# 47
# [15, 5, 3.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.32
# Epoch 5 training complete
# 5,0.24
# Epoch 6 training complete
# 6,0.45
# Epoch 7 training complete
# 7,0.27
# Epoch 8 training complete
# 8,0.31
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.48
# Epoch 11 training complete
# 11,0.43
# Epoch 12 training complete
# 12,0.4
# Epoch 13 training complete
# 13,0.55
# Epoch 14 training complete
# 14,0.49
# 0.5492045879364014
# 0.16058728944355685
# 54
# [15, 5, 3.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.18
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.28
# Epoch 6 training complete
# 6,0.22
# Epoch 7 training complete
# 7,0.34
# Epoch 8 training complete
# 8,0.38
# Epoch 9 training complete
# 9,0.42
# Epoch 10 training complete
# 10,0.46
# Epoch 11 training complete
# 11,0.45
# Epoch 12 training complete
# 12,0.6
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.61
# 0.6796488761901855
# 0.13188139524143283
# 23
# [15, 5, 5.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.2
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.15
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.02
# Epoch 10 training complete
# 10,0.02
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.19
# Epoch 13 training complete
# 13,0.24
# Epoch 14 training complete
# 14,0.26
# 0.3707277774810791
# 0.23234721570979658
# 40
# [15, 5, 5.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.18
# Epoch 1 training complete
# 1,0.25
# Epoch 2 training complete
# 2,0.53
# Epoch 3 training complete
# 3,0.61
# Epoch 4 training complete
# 4,0.66
# Epoch 5 training complete
# 5,0.64
# Epoch 6 training complete
# 6,0.68
# Epoch 7 training complete
# 7,0.69
# Epoch 8 training complete
# 8,0.72
# Epoch 9 training complete
# 9,0.7
# Epoch 10 training complete
# 10,0.71
# Epoch 11 training complete
# 11,0.71
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.72
# Epoch 14 training complete
# 14,0.71
# 0.5405929088592529
# 0.12317264253660791
# 66
# [15, 5, 5.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.11
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.07
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.1
# Epoch 14 training complete
# 14,0.14
# 1.209700584411621
# 0.2209410463419598
# 89
# [15, 5, 5.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.3
# Epoch 3 training complete
# 3,0.38
# Epoch 4 training complete
# 4,0.23
# Epoch 5 training complete
# 5,0.36
# Epoch 6 training complete
# 6,0.57
# Epoch 7 training complete
# 7,0.56
# Epoch 8 training complete
# 8,0.6
# Epoch 9 training complete
# 9,0.61
# Epoch 10 training complete
# 10,0.6
# Epoch 11 training complete
# 11,0.64
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.61
# 1.2058894634246826
# 0.21596808598594353
# 44
# [15, 5, 6.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.12
# Epoch 2 training complete
# 2,0.02
# Epoch 3 training complete
# 3,0.24
# Epoch 4 training complete
# 4,0.24
# Epoch 5 training complete
# 5,0.24
# Epoch 6 training complete
# 6,0.24
# Epoch 7 training complete
# 7,0.16
# Epoch 8 training complete
# 8,0.24
# Epoch 9 training complete
# 9,0.25
# Epoch 10 training complete
# 10,0.21
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.29
# Epoch 14 training complete
# 14,0.25
# 0.35176968574523926
# 0.11454113527244834
# 22
# [15, 5, 6.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.17
# Epoch 1 training complete
# 1,0.4
# Epoch 2 training complete
# 2,0.57
# Epoch 3 training complete
# 3,0.58
# Epoch 4 training complete
# 4,0.64
# Epoch 5 training complete
# 5,0.67
# Epoch 6 training complete
# 6,0.7
# Epoch 7 training complete
# 7,0.71
# Epoch 8 training complete
# 8,0.71
# Epoch 9 training complete
# 9,0.74
# Epoch 10 training complete
# 10,0.71
# Epoch 11 training complete
# 11,0.69
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.71
# 0.44556689262390137
# 0.1497488687972437
# 1
# [15, 5, 6.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.02
# Epoch 5 training complete
# 5,0.11
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.08
# Epoch 9 training complete
# 9,0.15
# Epoch 10 training complete
# 10,0.11
# Epoch 11 training complete
# 11,0.07
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.11
# 0.6738319396972656
# 0.26962013986317596
# 98
# [15, 5, 6.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.16
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.35
# Epoch 5 training complete
# 5,0.3
# Epoch 6 training complete
# 6,0.44
# Epoch 7 training complete
# 7,0.63
# Epoch 8 training complete
# 8,0.56
# Epoch 9 training complete
# 9,0.59
# Epoch 10 training complete
# 10,0.61
# Epoch 11 training complete
# 11,0.6
# Epoch 12 training complete
# 12,0.58
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.68
# 0.594186544418335
# 0.08873074883991468
# 63
# [15, 10, 0.1] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.12
# Epoch 1 training complete
# 1,0.19
# Epoch 2 training complete
# 2,0.23
# Epoch 3 training complete
# 3,0.21
# Epoch 4 training complete
# 4,0.48
# Epoch 5 training complete
# 5,0.46
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.47
# Epoch 8 training complete
# 8,0.55
# Epoch 9 training complete
# 9,0.57
# Epoch 10 training complete
# 10,0.56
# Epoch 11 training complete
# 11,0.55
# Epoch 12 training complete
# 12,0.58
# Epoch 13 training complete
# 13,0.56
# Epoch 14 training complete
# 14,0.55
# 0.3356330394744873
# 0.13040335307829926
# 34
# [15, 10, 0.1] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.02
# Epoch 2 training complete
# 2,0.02
# Epoch 3 training complete
# 3,0.02
# Epoch 4 training complete
# 4,0.04
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.09
# Epoch 7 training complete
# 7,0.15
# Epoch 8 training complete
# 8,0.18
# Epoch 9 training complete
# 9,0.19
# Epoch 10 training complete
# 10,0.21
# Epoch 11 training complete
# 11,0.21
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.2
# 0.42529797554016113
# 0.1423584400461467
# 68
# [15, 10, 0.1] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.2
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.16
# Epoch 4 training complete
# 4,0.21
# Epoch 5 training complete
# 5,0.2
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.21
# Epoch 10 training complete
# 10,0.1
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.22
# 0.5667304992675781
# 0.12263175217457543
# 85
# [15, 10, 0.1] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.07
# Epoch 1 training complete
# 1,0.07
# Epoch 2 training complete
# 2,0.07
# Epoch 3 training complete
# 3,0.07
# Epoch 4 training complete
# 4,0.1
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.1
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.12
# Epoch 9 training complete
# 9,0.15
# Epoch 10 training complete
# 10,0.16
# Epoch 11 training complete
# 11,0.1
# Epoch 12 training complete
# 12,0.08
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.08
# 0.6318783760070801
# 0.1459952940195725
# 68
# [15, 10, 0.5] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.23
# Epoch 1 training complete
# 1,0.38
# Epoch 2 training complete
# 2,0.58
# Epoch 3 training complete
# 3,0.62
# Epoch 4 training complete
# 4,0.66
# Epoch 5 training complete
# 5,0.66
# Epoch 6 training complete
# 6,0.67
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.68
# Epoch 9 training complete
# 9,0.71
# Epoch 10 training complete
# 10,0.71
# Epoch 11 training complete
# 11,0.71
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.71
# Epoch 14 training complete
# 14,0.71
# 0.4093656539916992
# 0.06151304042601688
# 66
# [15, 10, 0.5] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.13
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.19
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.24
# Epoch 5 training complete
# 5,0.29
# Epoch 6 training complete
# 6,0.3
# Epoch 7 training complete
# 7,0.33
# Epoch 8 training complete
# 8,0.36
# Epoch 9 training complete
# 9,0.39
# Epoch 10 training complete
# 10,0.43
# Epoch 11 training complete
# 11,0.48
# Epoch 12 training complete
# 12,0.49
# Epoch 13 training complete
# 13,0.49
# Epoch 14 training complete
# 14,0.49
# 0.4084441661834717
# 0.16232976262539006
# 36
# [15, 10, 0.5] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.2
# Epoch 5 training complete
# 5,0.15
# Epoch 6 training complete
# 6,0.16
# Epoch 7 training complete
# 7,0.19
# Epoch 8 training complete
# 8,0.29
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.4
# Epoch 11 training complete
# 11,0.43
# Epoch 12 training complete
# 12,0.44
# Epoch 13 training complete
# 13,0.49
# Epoch 14 training complete
# 14,0.53
# 0.541867733001709
# 0.10485686640779279
# 11
# [15, 10, 0.5] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.13
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.17
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.17
# Epoch 10 training complete
# 10,0.17
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.15
# Epoch 13 training complete
# 13,0.15
# Epoch 14 training complete
# 14,0.18
# 0.659935712814331
# 0.1362297209388396
# 3
# [15, 10, 1.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.45
# Epoch 1 training complete
# 1,0.38
# Epoch 2 training complete
# 2,0.53
# Epoch 3 training complete
# 3,0.59
# Epoch 4 training complete
# 4,0.64
# Epoch 5 training complete
# 5,0.64
# Epoch 6 training complete
# 6,0.73
# Epoch 7 training complete
# 7,0.74
# Epoch 8 training complete
# 8,0.72
# Epoch 9 training complete
# 9,0.73
# Epoch 10 training complete
# 10,0.7
# Epoch 11 training complete
# 11,0.73
# Epoch 12 training complete
# 12,0.74
# Epoch 13 training complete
# 13,0.74
# Epoch 14 training complete
# 14,0.72
# 0.42629098892211914
# 0.08534097980621136
# 11
# [15, 10, 1.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.12
# Epoch 1 training complete
# 1,0.31
# Epoch 2 training complete
# 2,0.35
# Epoch 3 training complete
# 3,0.45
# Epoch 4 training complete
# 4,0.51
# Epoch 5 training complete
# 5,0.58
# Epoch 6 training complete
# 6,0.63
# Epoch 7 training complete
# 7,0.64
# Epoch 8 training complete
# 8,0.6
# Epoch 9 training complete
# 9,0.6
# Epoch 10 training complete
# 10,0.66
# Epoch 11 training complete
# 11,0.62
# Epoch 12 training complete
# 12,0.63
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.62
# 0.865452766418457
# 0.19528751809276365
# 11
# [15, 10, 1.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.41
# Epoch 5 training complete
# 5,0.47
# Epoch 6 training complete
# 6,0.47
# Epoch 7 training complete
# 7,0.42
# Epoch 8 training complete
# 8,0.47
# Epoch 9 training complete
# 9,0.49
# Epoch 10 training complete
# 10,0.5
# Epoch 11 training complete
# 11,0.51
# Epoch 12 training complete
# 12,0.53
# Epoch 13 training complete
# 13,0.51
# Epoch 14 training complete
# 14,0.55
# 1.4104788303375244
# 0.13390877961706874
# 47
# [15, 10, 1.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.19
# Epoch 11 training complete
# 11,0.16
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.1
# 0.9275937080383301
# 0.13783653021968525
# 91
# [15, 10, 3.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.23
# Epoch 2 training complete
# 2,0.37
# Epoch 3 training complete
# 3,0.28
# Epoch 4 training complete
# 4,0.48
# Epoch 5 training complete
# 5,0.41
# Epoch 6 training complete
# 6,0.61
# Epoch 7 training complete
# 7,0.6
# Epoch 8 training complete
# 8,0.56
# Epoch 9 training complete
# 9,0.52
# Epoch 10 training complete
# 10,0.64
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.66
# Epoch 13 training complete
# 13,0.61
# Epoch 14 training complete
# 14,0.64
# 0.34955763816833496
# 0.15969706970953954
# 59
# [15, 10, 3.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.2
# Epoch 1 training complete
# 1,0.28
# Epoch 2 training complete
# 2,0.42
# Epoch 3 training complete
# 3,0.51
# Epoch 4 training complete
# 4,0.57
# Epoch 5 training complete
# 5,0.59
# Epoch 6 training complete
# 6,0.66
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.67
# Epoch 9 training complete
# 9,0.69
# Epoch 10 training complete
# 10,0.69
# Epoch 11 training complete
# 11,0.7
# Epoch 12 training complete
# 12,0.7
# Epoch 13 training complete
# 13,0.7
# Epoch 14 training complete
# 14,0.72
# 0.3982205390930176
# 0.17327474858984385
# 44
# [15, 10, 3.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.29
# Epoch 2 training complete
# 2,0.17
# Epoch 3 training complete
# 3,0.22
# Epoch 4 training complete
# 4,0.45
# Epoch 5 training complete
# 5,0.55
# Epoch 6 training complete
# 6,0.57
# Epoch 7 training complete
# 7,0.63
# Epoch 8 training complete
# 8,0.57
# Epoch 9 training complete
# 9,0.71
# Epoch 10 training complete
# 10,0.72
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.7
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.65
# 0.6003568172454834
# 0.10711798270920972
# 44
# [15, 10, 3.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.26
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.19
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.35
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.25
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.25
# Epoch 13 training complete
# 13,0.3
# Epoch 14 training complete
# 14,0.34
# 0.5797898769378662
# 0.1385071748344047
# 98
# [15, 10, 5.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.18
# Epoch 2 training complete
# 2,0.18
# Epoch 3 training complete
# 3,0.2
# Epoch 4 training complete
# 4,0.28
# Epoch 5 training complete
# 5,0.3
# Epoch 6 training complete
# 6,0.37
# Epoch 7 training complete
# 7,0.43
# Epoch 8 training complete
# 8,0.39
# Epoch 9 training complete
# 9,0.35
# Epoch 10 training complete
# 10,0.26
# Epoch 11 training complete
# 11,0.17
# Epoch 12 training complete
# 12,0.42
# Epoch 13 training complete
# 13,0.35
# Epoch 14 training complete
# 14,0.47
# 0.3643820285797119
# 0.0750809919943951
# 1
# [15, 10, 5.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.23
# Epoch 1 training complete
# 1,0.34
# Epoch 2 training complete
# 2,0.46
# Epoch 3 training complete
# 3,0.67
# Epoch 4 training complete
# 4,0.56
# Epoch 5 training complete
# 5,0.63
# Epoch 6 training complete
# 6,0.65
# Epoch 7 training complete
# 7,0.67
# Epoch 8 training complete
# 8,0.66
# Epoch 9 training complete
# 9,0.65
# Epoch 10 training complete
# 10,0.71
# Epoch 11 training complete
# 11,0.68
# Epoch 12 training complete
# 12,0.68
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.68
# 0.3633747100830078
# 0.15005382075786602
# 11
# [15, 10, 5.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.21
# Epoch 8 training complete
# 8,0.28
# Epoch 9 training complete
# 9,0.11
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.2
# Epoch 13 training complete
# 13,0.25
# Epoch 14 training complete
# 14,0.22
# 0.5679681301116943
# 0.19020132625222064
# 94
# [15, 10, 5.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.25
# Epoch 2 training complete
# 2,0.16
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.25
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.47
# Epoch 10 training complete
# 10,0.52
# Epoch 11 training complete
# 11,0.62
# Epoch 12 training complete
# 12,0.57
# Epoch 13 training complete
# 13,0.6
# Epoch 14 training complete
# 14,0.61
# 0.6591670513153076
# 0.17122424965919292
# 35
# [15, 10, 6.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.21
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.1
# Epoch 9 training complete
# 9,0.11
# Epoch 10 training complete
# 10,0.1
# Epoch 11 training complete
# 11,0.16
# Epoch 12 training complete
# 12,0.17
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.2
# 0.36061644554138184
# 0.5168513016502054
# 24
# [15, 10, 6.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.22
# Epoch 1 training complete
# 1,0.24
# Epoch 2 training complete
# 2,0.51
# Epoch 3 training complete
# 3,0.5
# Epoch 4 training complete
# 4,0.58
# Epoch 5 training complete
# 5,0.62
# Epoch 6 training complete
# 6,0.62
# Epoch 7 training complete
# 7,0.65
# Epoch 8 training complete
# 8,0.57
# Epoch 9 training complete
# 9,0.61
# Epoch 10 training complete
# 10,0.6
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.65
# Epoch 13 training complete
# 13,0.69
# Epoch 14 training complete
# 14,0.7
# 0.44448089599609375
# 0.1675396641011566
# 61
# [15, 10, 6.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.11
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.15
# Epoch 10 training complete
# 10,0.16
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.11
# Epoch 13 training complete
# 13,0.1
# Epoch 14 training complete
# 14,0.08
# 0.5785748958587646
# 0.18256470548455916
# 91
# [15, 10, 6.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.27
# Epoch 4 training complete
# 4,0.29
# Epoch 5 training complete
# 5,0.4
# Epoch 6 training complete
# 6,0.24
# Epoch 7 training complete
# 7,0.33
# Epoch 8 training complete
# 8,0.43
# Epoch 9 training complete
# 9,0.42
# Epoch 10 training complete
# 10,0.58
# Epoch 11 training complete
# 11,0.53
# Epoch 12 training complete
# 12,0.61
# Epoch 13 training complete
# 13,0.59
# Epoch 14 training complete
# 14,0.58
# 0.6261796951293945
# 0.08687513655013615
# 35
# [15, 20, 0.1] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.18
# Epoch 3 training complete
# 3,0.18
# Epoch 4 training complete
# 4,0.18
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.23
# Epoch 7 training complete
# 7,0.24
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.27
# Epoch 10 training complete
# 10,0.28
# Epoch 11 training complete
# 11,0.28
# Epoch 12 training complete
# 12,0.3
# Epoch 13 training complete
# 13,0.3
# Epoch 14 training complete
# 14,0.33
# 0.37793898582458496
# 0.13344826855300904
# 20
# [15, 20, 0.1] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.15
# Epoch 4 training complete
# 4,0.15
# Epoch 5 training complete
# 5,0.15
# Epoch 6 training complete
# 6,0.15
# Epoch 7 training complete
# 7,0.2
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.19
# Epoch 10 training complete
# 10,0.2
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.19
# Epoch 13 training complete
# 13,0.18
# Epoch 14 training complete
# 14,0.2
# 0.6831023693084717
# 0.18112965913145895
# 68
# [15, 20, 0.1] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 1.3461871147155762
# 0.1348705301344327
# 51
# [15, 20, 0.1] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.08
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.08
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.08
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.08
# 0.9735908508300781
# 0.2175200194992635
# 95
# [15, 20, 0.5] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.38
# Epoch 2 training complete
# 2,0.48
# Epoch 3 training complete
# 3,0.39
# Epoch 4 training complete
# 4,0.59
# Epoch 5 training complete
# 5,0.48
# Epoch 6 training complete
# 6,0.63
# Epoch 7 training complete
# 7,0.59
# Epoch 8 training complete
# 8,0.62
# Epoch 9 training complete
# 9,0.64
# Epoch 10 training complete
# 10,0.62
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.69
# Epoch 13 training complete
# 13,0.65
# Epoch 14 training complete
# 14,0.61
# 0.3550987243652344
# 0.12697109209730756
# 63
# [15, 20, 0.5] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.2
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.21
# Epoch 4 training complete
# 4,0.21
# Epoch 5 training complete
# 5,0.21
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.22
# Epoch 8 training complete
# 8,0.23
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.25
# Epoch 11 training complete
# 11,0.25
# Epoch 12 training complete
# 12,0.26
# Epoch 13 training complete
# 13,0.3
# Epoch 14 training complete
# 14,0.31
# 0.4050722122192383
# 0.15264633805134564
# 23
# [15, 20, 0.5] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.15
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.28
# Epoch 7 training complete
# 7,0.3
# Epoch 8 training complete
# 8,0.39
# Epoch 9 training complete
# 9,0.2
# Epoch 10 training complete
# 10,0.32
# Epoch 11 training complete
# 11,0.33
# Epoch 12 training complete
# 12,0.3
# Epoch 13 training complete
# 13,0.32
# Epoch 14 training complete
# 14,0.39
# 0.6286942958831787
# 0.12627738424644705
# 36
# [15, 20, 0.5] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.5901875495910645
# 0.135795002888117
# 93
# [15, 20, 1.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.2
# Epoch 1 training complete
# 1,0.32
# Epoch 2 training complete
# 2,0.5
# Epoch 3 training complete
# 3,0.55
# Epoch 4 training complete
# 4,0.56
# Epoch 5 training complete
# 5,0.65
# Epoch 6 training complete
# 6,0.64
# Epoch 7 training complete
# 7,0.66
# Epoch 8 training complete
# 8,0.65
# Epoch 9 training complete
# 9,0.68
# Epoch 10 training complete
# 10,0.72
# Epoch 11 training complete
# 11,0.67
# Epoch 12 training complete
# 12,0.71
# Epoch 13 training complete
# 13,0.72
# Epoch 14 training complete
# 14,0.76
# 0.3886251449584961
# 0.08392516655472718
# 54
# [15, 20, 1.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.19
# Epoch 1 training complete
# 1,0.21
# Epoch 2 training complete
# 2,0.21
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.21
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.25
# Epoch 8 training complete
# 8,0.29
# Epoch 9 training complete
# 9,0.33
# Epoch 10 training complete
# 10,0.36
# Epoch 11 training complete
# 11,0.36
# Epoch 12 training complete
# 12,0.35
# Epoch 13 training complete
# 13,0.37
# Epoch 14 training complete
# 14,0.36
# 0.44156551361083984
# 0.1593928146520266
# 6
# [15, 20, 1.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.23
# Epoch 2 training complete
# 2,0.16
# Epoch 3 training complete
# 3,0.19
# Epoch 4 training complete
# 4,0.18
# Epoch 5 training complete
# 5,0.16
# Epoch 6 training complete
# 6,0.27
# Epoch 7 training complete
# 7,0.24
# Epoch 8 training complete
# 8,0.3
# Epoch 9 training complete
# 9,0.39
# Epoch 10 training complete
# 10,0.36
# Epoch 11 training complete
# 11,0.4
# Epoch 12 training complete
# 12,0.53
# Epoch 13 training complete
# 13,0.5
# Epoch 14 training complete
# 14,0.59
# 0.5806493759155273
# 0.1040189176844559
# 11
# [15, 20, 1.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6187922954559326
# 0.14161367039826586
# 55
# [15, 20, 3.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.37
# Epoch 5 training complete
# 5,0.35
# Epoch 6 training complete
# 6,0.46
# Epoch 7 training complete
# 7,0.47
# Epoch 8 training complete
# 8,0.57
# Epoch 9 training complete
# 9,0.58
# Epoch 10 training complete
# 10,0.57
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.54
# Epoch 13 training complete
# 13,0.66
# Epoch 14 training complete
# 14,0.7
# 0.34316468238830566
# 0.10176857448242999
# 84
# [15, 20, 3.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.25
# Epoch 1 training complete
# 1,0.22
# Epoch 2 training complete
# 2,0.28
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.34
# Epoch 6 training complete
# 6,0.45
# Epoch 7 training complete
# 7,0.44
# Epoch 8 training complete
# 8,0.48
# Epoch 9 training complete
# 9,0.44
# Epoch 10 training complete
# 10,0.49
# Epoch 11 training complete
# 11,0.48
# Epoch 12 training complete
# 12,0.51
# Epoch 13 training complete
# 13,0.54
# Epoch 14 training complete
# 14,0.52
# 0.36841821670532227
# 0.2100729071083004
# 59
# [15, 20, 3.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.22
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.17
# Epoch 3 training complete
# 3,0.21
# Epoch 4 training complete
# 4,0.22
# Epoch 5 training complete
# 5,0.25
# Epoch 6 training complete
# 6,0.28
# Epoch 7 training complete
# 7,0.35
# Epoch 8 training complete
# 8,0.4
# Epoch 9 training complete
# 9,0.5
# Epoch 10 training complete
# 10,0.37
# Epoch 11 training complete
# 11,0.55
# Epoch 12 training complete
# 12,0.52
# Epoch 13 training complete
# 13,0.42
# Epoch 14 training complete
# 14,0.62
# 0.6543176174163818
# 0.11036486880081947
# 38
# [15, 20, 3.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.22
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.19
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.22
# Epoch 11 training complete
# 11,0.26
# Epoch 12 training complete
# 12,0.17
# Epoch 13 training complete
# 13,0.11
# Epoch 14 training complete
# 14,0.28
# 0.6797301769256592
# 0.1261031246555981
# 91
# [15, 20, 5.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.18
# Epoch 3 training complete
# 3,0.23
# Epoch 4 training complete
# 4,0.2
# Epoch 5 training complete
# 5,0.26
# Epoch 6 training complete
# 6,0.21
# Epoch 7 training complete
# 7,0.26
# Epoch 8 training complete
# 8,0.28
# Epoch 9 training complete
# 9,0.35
# Epoch 10 training complete
# 10,0.34
# Epoch 11 training complete
# 11,0.29
# Epoch 12 training complete
# 12,0.44
# Epoch 13 training complete
# 13,0.38
# Epoch 14 training complete
# 14,0.39
# 0.3400418758392334
# 0.14209965384269818
# 53
# [15, 20, 5.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.25
# Epoch 2 training complete
# 2,0.38
# Epoch 3 training complete
# 3,0.41
# Epoch 4 training complete
# 4,0.41
# Epoch 5 training complete
# 5,0.41
# Epoch 6 training complete
# 6,0.55
# Epoch 7 training complete
# 7,0.55
# Epoch 8 training complete
# 8,0.57
# Epoch 9 training complete
# 9,0.55
# Epoch 10 training complete
# 10,0.62
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.65
# Epoch 13 training complete
# 13,0.67
# Epoch 14 training complete
# 14,0.66
# 0.5406007766723633
# 0.10804448483650733
# 11
# [15, 20, 5.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.09
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.22
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.3
# 1.469149112701416
# 0.14964784627884659
# 53
# [15, 20, 5.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.2
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.22
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.21
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.08
# Epoch 11 training complete
# 11,0.22
# Epoch 12 training complete
# 12,0.31
# Epoch 13 training complete
# 13,0.31
# Epoch 14 training complete
# 14,0.31
# 1.3791882991790771
# 0.13622566082186016
# 61
# [15, 20, 6.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.19
# Epoch 5 training complete
# 5,0.16
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.22
# Epoch 9 training complete
# 9,0.22
# Epoch 10 training complete
# 10,0.07
# Epoch 11 training complete
# 11,0.23
# Epoch 12 training complete
# 12,0.36
# Epoch 13 training complete
# 13,0.35
# Epoch 14 training complete
# 14,0.28
# 0.36136698722839355
# 0.25565501854542294
# 55
# [15, 20, 6.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.08
# Epoch 1 training complete
# 1,0.11
# Epoch 2 training complete
# 2,0.38
# Epoch 3 training complete
# 3,0.41
# Epoch 4 training complete
# 4,0.39
# Epoch 5 training complete
# 5,0.5
# Epoch 6 training complete
# 6,0.39
# Epoch 7 training complete
# 7,0.54
# Epoch 8 training complete
# 8,0.54
# Epoch 9 training complete
# 9,0.62
# Epoch 10 training complete
# 10,0.59
# Epoch 11 training complete
# 11,0.65
# Epoch 12 training complete
# 12,0.64
# Epoch 13 training complete
# 13,0.65
# Epoch 14 training complete
# 14,0.63
# 0.39730167388916016
# 0.17633835945482298
# 61
# [15, 20, 6.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.15
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.11
# Epoch 13 training complete
# 13,0.19
# Epoch 14 training complete
# 14,0.11
# 0.5581421852111816
# 0.147630547490268
# 24
# [15, 20, 6.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.21
# Epoch 2 training complete
# 2,0.23
# Epoch 3 training complete
# 3,0.11
# Epoch 4 training complete
# 4,0.21
# Epoch 5 training complete
# 5,0.09
# Epoch 6 training complete
# 6,0.27
# Epoch 7 training complete
# 7,0.21
# Epoch 8 training complete
# 8,0.33
# Epoch 9 training complete
# 9,0.32
# Epoch 10 training complete
# 10,0.28
# Epoch 11 training complete
# 11,0.32
# Epoch 12 training complete
# 12,0.46
# Epoch 13 training complete
# 13,0.44
# Epoch 14 training complete
# 14,0.47
# 0.6315970420837402
# 0.16905754944379175
# 62
# [15, 100, 0.1] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.02
# Epoch 1 training complete
# 1,0.02
# Epoch 2 training complete
# 2,0.02
# Epoch 3 training complete
# 3,0.02
# Epoch 4 training complete
# 4,0.05
# Epoch 5 training complete
# 5,0.11
# Epoch 6 training complete
# 6,0.11
# Epoch 7 training complete
# 7,0.11
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.1
# Epoch 10 training complete
# 10,0.1
# Epoch 11 training complete
# 11,0.1
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.12
# Epoch 14 training complete
# 14,0.15
# 0.3930187225341797
# 0.13808712172855875
# 25
# [15, 100, 0.1] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.04
# Epoch 1 training complete
# 1,0.04
# Epoch 2 training complete
# 2,0.04
# Epoch 3 training complete
# 3,0.04
# Epoch 4 training complete
# 4,0.04
# Epoch 5 training complete
# 5,0.04
# Epoch 6 training complete
# 6,0.04
# Epoch 7 training complete
# 7,0.04
# Epoch 8 training complete
# 8,0.04
# Epoch 9 training complete
# 9,0.04
# Epoch 10 training complete
# 10,0.04
# Epoch 11 training complete
# 11,0.05
# Epoch 12 training complete
# 12,0.05
# Epoch 13 training complete
# 13,0.06
# Epoch 14 training complete
# 14,0.07
# 0.3842787742614746
# 0.4489677226120916
# 93
# [15, 100, 0.1] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.1
# Epoch 4 training complete
# 4,0.1
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.1
# Epoch 7 training complete
# 7,0.1
# Epoch 8 training complete
# 8,0.1
# Epoch 9 training complete
# 9,0.1
# Epoch 10 training complete
# 10,0.1
# Epoch 11 training complete
# 11,0.13
# Epoch 12 training complete
# 12,0.16
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.5786426067352295
# 0.17687269236449046
# 93
# [15, 100, 0.1] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.07
# Epoch 1 training complete
# 1,0.07
# Epoch 2 training complete
# 2,0.07
# Epoch 3 training complete
# 3,0.07
# Epoch 4 training complete
# 4,0.07
# Epoch 5 training complete
# 5,0.07
# Epoch 6 training complete
# 6,0.07
# Epoch 7 training complete
# 7,0.07
# Epoch 8 training complete
# 8,0.07
# Epoch 9 training complete
# 9,0.07
# Epoch 10 training complete
# 10,0.07
# Epoch 11 training complete
# 11,0.07
# Epoch 12 training complete
# 12,0.07
# Epoch 13 training complete
# 13,0.07
# Epoch 14 training complete
# 14,0.07
# 0.6144990921020508
# 0.47923153775448885
# 48
# [15, 100, 0.5] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.1
# Epoch 2 training complete
# 2,0.26
# Epoch 3 training complete
# 3,0.26
# Epoch 4 training complete
# 4,0.27
# Epoch 5 training complete
# 5,0.3
# Epoch 6 training complete
# 6,0.38
# Epoch 7 training complete
# 7,0.44
# Epoch 8 training complete
# 8,0.47
# Epoch 9 training complete
# 9,0.53
# Epoch 10 training complete
# 10,0.55
# Epoch 11 training complete
# 11,0.56
# Epoch 12 training complete
# 12,0.57
# Epoch 13 training complete
# 13,0.62
# Epoch 14 training complete
# 14,0.64
# 0.34848880767822266
# 0.1338931859597665
# 82
# [15, 100, 0.5] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.14
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.14
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.13
# Epoch 5 training complete
# 5,0.17
# Epoch 6 training complete
# 6,0.18
# Epoch 7 training complete
# 7,0.18
# Epoch 8 training complete
# 8,0.18
# Epoch 9 training complete
# 9,0.18
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.17
# Epoch 12 training complete
# 12,0.17
# Epoch 13 training complete
# 13,0.2
# Epoch 14 training complete
# 14,0.22
# 0.42725324630737305
# 0.1568638849335582
# 82
# [15, 100, 0.5] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.1
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.2
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# 0.6113700866699219
# 0.13470774269533078
# 25
# [15, 100, 0.5] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.07
# Epoch 1 training complete
# 1,0.07
# Epoch 2 training complete
# 2,0.07
# Epoch 3 training complete
# 3,0.07
# Epoch 4 training complete
# 4,0.07
# Epoch 5 training complete
# 5,0.07
# Epoch 6 training complete
# 6,0.07
# Epoch 7 training complete
# 7,0.07
# Epoch 8 training complete
# 8,0.08
# Epoch 9 training complete
# 9,0.12
# Epoch 10 training complete
# 10,0.17
# Epoch 11 training complete
# 11,0.19
# Epoch 12 training complete
# 12,0.25
# Epoch 13 training complete
# 13,0.24
# Epoch 14 training complete
# 14,0.25
# 0.5807507038116455
# 0.16621409903869985
# 25
# [15, 100, 1.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.24
# Epoch 2 training complete
# 2,0.29
# Epoch 3 training complete
# 3,0.33
# Epoch 4 training complete
# 4,0.38
# Epoch 5 training complete
# 5,0.41
# Epoch 6 training complete
# 6,0.45
# Epoch 7 training complete
# 7,0.48
# Epoch 8 training complete
# 8,0.48
# ...
# 51,0.22
# Epoch 52 training complete
# 52,0.22
# Epoch 53 training complete
# 53,0.23
# Epoch 54 training complete
# 54,0.23
# Epoch 55 training complete
# 55,0.26
# Epoch 56 training complete
# 56,0.27
# Epoch 57 training complete
# 57,0.27
# Epoch 58 training complete
# 58,0.28
# Epoch 59 training complete
# 59,0.3
# Epoch 60 training complete
# 60,0.31
# Epoch 61 training complete
# 61,0.31
# Epoch 62 training complete
# 62,0.31
# Epoch 63 training complete
# 63,0.33
# Epoch 64 training complete
# 64,0.33
# Epoch 65 training complete
# 65,0.34
# Epoch 66 training complete
# 66,0.34
# Epoch 67 training complete
# 67,0.36
# Epoch 68 training complete
# 68,0.36
# Epoch 69 training complete
# 69,0.37
# Epoch 70 training complete
# 70,0.4
# Epoch 71 training complete
# 71,0.4
# Epoch 72 training complete
# 72,0.4
# Epoch 73 training complete
# 73,0.4
# Epoch 74 training complete
# 74,0.4
# Epoch 75 training complete
# 75,0.42
# Epoch 76 training complete
# 76,0.42
# Epoch 77 training complete
# 77,0.44
# Epoch 78 training complete
# 78,0.44
# Epoch 79 training complete
# 79,0.44
# Epoch 80 training complete
# 80,0.44
# Epoch 81 training complete
# 81,0.44
# Epoch 82 training complete
# 82,0.44
# Epoch 83 training complete
# 83,0.44
# Epoch 84 training complete
# 84,0.45
# Epoch 85 training complete
# 85,0.46
# Epoch 86 training complete
# 86,0.47
# Epoch 87 training complete
# 87,0.49
# Epoch 88 training complete
# 88,0.49
# Epoch 89 training complete
# 89,0.5
# Epoch 90 training complete
# 90,0.5
# Epoch 91 training complete
# 91,0.5
# Epoch 92 training complete
# 92,0.49
# Epoch 93 training complete
# 93,0.49
# Epoch 94 training complete
# 94,0.49
# Epoch 95 training complete
# 95,0.49
# Epoch 96 training complete
# 96,0.51
# Epoch 97 training complete
# 97,0.51
# Epoch 98 training complete
# 98,0.51
# Epoch 99 training complete
# 99,0.51
# 4.98289942741394
# 0.1683916070568125
# 11
# [100, 100, 6.0] Single Hidden Layer plus Cross-Entropy
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.1
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.1
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.11
# Epoch 9 training complete
# 9,0.24
# Epoch 10 training complete
# 10,0.17
# Epoch 11 training complete
# 11,0.13
# Epoch 12 training complete
# 12,0.1
# Epoch 13 training complete
# 13,0.08
# Epoch 14 training complete
# 14,0.26
# Epoch 15 training complete
# 15,0.23
# Epoch 16 training complete
# 16,0.14
# Epoch 17 training complete
# 17,0.1
# Epoch 18 training complete
# 18,0.14
# Epoch 19 training complete
# 19,0.11
# Epoch 20 training complete
# 20,0.27
# Epoch 21 training complete
# 21,0.24
# Epoch 22 training complete
# 22,0.26
# Epoch 23 training complete
# 23,0.11
# Epoch 24 training complete
# 24,0.23
# Epoch 25 training complete
# 25,0.18
# Epoch 26 training complete
# 26,0.19
# Epoch 27 training complete
# 27,0.18
# Epoch 28 training complete
# 28,0.23
# Epoch 29 training complete
# 29,0.25
# Epoch 30 training complete
# 30,0.21
# Epoch 31 training complete
# 31,0.19
# Epoch 32 training complete
# 32,0.21
# Epoch 33 training complete
# 33,0.26
# Epoch 34 training complete
# 34,0.15
# Epoch 35 training complete
# 35,0.23
# Epoch 36 training complete
# 36,0.15
# Epoch 37 training complete
# 37,0.26
# Epoch 38 training complete
# 38,0.19
# Epoch 39 training complete
# 39,0.18
# Epoch 40 training complete
# 40,0.16
# Epoch 41 training complete
# 41,0.26
# Epoch 42 training complete
# 42,0.21
# Epoch 43 training complete
# 43,0.18
# Epoch 44 training complete
# 44,0.21
# Epoch 45 training complete
# 45,0.19
# Epoch 46 training complete
# 46,0.18
# Epoch 47 training complete
# 47,0.38
# Epoch 48 training complete
# 48,0.32
# Epoch 49 training complete
# 49,0.34
# Epoch 50 training complete
# 50,0.22
# Epoch 51 training complete
# 51,0.23
# Epoch 52 training complete
# 52,0.21
# Epoch 53 training complete
# 53,0.27
# Epoch 54 training complete
# 54,0.15
# Epoch 55 training complete
# 55,0.2
# Epoch 56 training complete
# 56,0.21
# Epoch 57 training complete
# 57,0.24
# Epoch 58 training complete
# 58,0.15
# Epoch 59 training complete
# 59,0.2
# Epoch 60 training complete
# 60,0.09
# Epoch 61 training complete
# 61,0.26
# Epoch 62 training complete
# 62,0.18
# Epoch 63 training complete
# 63,0.2
# Epoch 64 training complete
# 64,0.21
# Epoch 65 training complete
# 65,0.24
# Epoch 66 training complete
# 66,0.15
# Epoch 67 training complete
# 67,0.26
# Epoch 68 training complete
# 68,0.19
# Epoch 69 training complete
# 69,0.27
# Epoch 70 training complete
# 70,0.09
# Epoch 71 training complete
# 71,0.29
# Epoch 72 training complete
# 72,0.22
# Epoch 73 training complete
# 73,0.2
# Epoch 74 training complete
# 74,0.18
# Epoch 75 training complete
# 75,0.26
# Epoch 76 training complete
# 76,0.15
# Epoch 77 training complete
# 77,0.23
# Epoch 78 training complete
# 78,0.08
# Epoch 79 training complete
# 79,0.34
# Epoch 80 training complete
# 80,0.09
# Epoch 81 training complete
# 81,0.25
# Epoch 82 training complete
# 82,0.29
# Epoch 83 training complete
# 83,0.32
# Epoch 84 training complete
# 84,0.19
# Epoch 85 training complete
# 85,0.34
# Epoch 86 training complete
# 86,0.16
# Epoch 87 training complete
# 87,0.29
# Epoch 88 training complete
# 88,0.21
# Epoch 89 training complete
# 89,0.28
# Epoch 90 training complete
# 90,0.27
# Epoch 91 training complete
# 91,0.32
# Epoch 92 training complete
# 92,0.23
# Epoch 93 training complete
# 93,0.37
# Epoch 94 training complete
# 94,0.23
# Epoch 95 training complete
# 95,0.3
# Epoch 96 training complete
# 96,0.25
# Epoch 97 training complete
# 97,0.13
# Epoch 98 training complete
# 98,0.28
# Epoch 99 training complete
# 99,0.31
# 4.164376258850098
# 0.1254524492703865
# 23
# [100, 100, 6.0] Single Hidden Layer Plus Quadratic
# Epoch 0 training complete
# 0,0.15
# Epoch 1 training complete
# 1,0.15
# Epoch 2 training complete
# 2,0.15
# Epoch 3 training complete
# 3,0.16
# Epoch 4 training complete
# 4,0.16
# Epoch 5 training complete
# 5,0.19
# Epoch 6 training complete
# 6,0.28
# Epoch 7 training complete
# 7,0.28
# Epoch 8 training complete
# 8,0.27
# Epoch 9 training complete
# 9,0.34
# Epoch 10 training complete
# 10,0.37
# Epoch 11 training complete
# 11,0.41
# Epoch 12 training complete
# 12,0.47
# Epoch 13 training complete
# 13,0.47
# Epoch 14 training complete
# 14,0.47
# Epoch 15 training complete
# 15,0.5
# Epoch 16 training complete
# 16,0.5
# Epoch 17 training complete
# 17,0.51
# Epoch 18 training complete
# 18,0.52
# Epoch 19 training complete
# 19,0.53
# Epoch 20 training complete
# 20,0.53
# Epoch 21 training complete
# 21,0.53
# Epoch 22 training complete
# 22,0.53
# Epoch 23 training complete
# 23,0.53
# Epoch 24 training complete
# 24,0.52
# Epoch 25 training complete
# 25,0.53
# Epoch 26 training complete
# 26,0.53
# Epoch 27 training complete
# 27,0.52
# Epoch 28 training complete
# 28,0.52
# Epoch 29 training complete
# 29,0.53
# Epoch 30 training complete
# 30,0.55
# Epoch 31 training complete
# 31,0.56
# Epoch 32 training complete
# 32,0.59
# Epoch 33 training complete
# 33,0.61
# Epoch 34 training complete
# 34,0.61
# Epoch 35 training complete
# 35,0.62
# Epoch 36 training complete
# 36,0.63
# Epoch 37 training complete
# 37,0.64
# Epoch 38 training complete
# 38,0.64
# Epoch 39 training complete
# 39,0.65
# Epoch 40 training complete
# 40,0.65
# Epoch 41 training complete
# 41,0.67
# Epoch 42 training complete
# 42,0.66
# Epoch 43 training complete
# 43,0.66
# Epoch 44 training complete
# 44,0.66
# Epoch 45 training complete
# 45,0.67
# Epoch 46 training complete
# 46,0.67
# Epoch 47 training complete
# 47,0.67
# Epoch 48 training complete
# 48,0.67
# Epoch 49 training complete
# 49,0.67
# Epoch 50 training complete
# 50,0.68
# Epoch 51 training complete
# 51,0.68
# Epoch 52 training complete
# 52,0.67
# Epoch 53 training complete
# 53,0.67
# Epoch 54 training complete
# 54,0.67
# Epoch 55 training complete
# 55,0.66
# Epoch 56 training complete
# 56,0.67
# Epoch 57 training complete
# 57,0.67
# Epoch 58 training complete
# 58,0.67
# Epoch 59 training complete
# 59,0.67
# Epoch 60 training complete
# 60,0.67
# Epoch 61 training complete
# 61,0.67
# Epoch 62 training complete
# 62,0.67
# Epoch 63 training complete
# 63,0.67
# Epoch 64 training complete
# 64,0.67
# Epoch 65 training complete
# 65,0.67
# Epoch 66 training complete
# 66,0.67
# Epoch 67 training complete
# 67,0.67
# Epoch 68 training complete
# 68,0.67
# Epoch 69 training complete
# 69,0.67
# Epoch 70 training complete
# 70,0.66
# Epoch 71 training complete
# 71,0.66
# Epoch 72 training complete
# 72,0.66
# Epoch 73 training complete
# 73,0.67
# Epoch 74 training complete
# 74,0.67
# Epoch 75 training complete
# 75,0.67
# Epoch 76 training complete
# 76,0.67
# Epoch 77 training complete
# 77,0.67
# Epoch 78 training complete
# 78,0.67
# Epoch 79 training complete
# 79,0.67
# Epoch 80 training complete
# 80,0.67
# Epoch 81 training complete
# 81,0.67
# Epoch 82 training complete
# 82,0.67
# Epoch 83 training complete
# 83,0.67
# Epoch 84 training complete
# 84,0.67
# Epoch 85 training complete
# 85,0.67
# Epoch 86 training complete
# 86,0.67
# Epoch 87 training complete
# 87,0.68
# Epoch 88 training complete
# 88,0.68
# Epoch 89 training complete
# 89,0.68
# Epoch 90 training complete
# 90,0.68
# Epoch 91 training complete
# 91,0.68
# Epoch 92 training complete
# 92,0.68
# Epoch 93 training complete
# 93,0.68
# Epoch 94 training complete
# 94,0.68
# Epoch 95 training complete
# 95,0.67
# Epoch 96 training complete
# 96,0.67
# Epoch 97 training complete
# 97,0.67
# Epoch 98 training complete
# 98,0.67
# Epoch 99 training complete
# 99,0.67
# 3.934546947479248
# 0.09612167588811504
# 11
# [100, 100, 6.0] Dual Hidden Layers Plus Cross-Entropy
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.14
# Epoch 2 training complete
# 2,0.11
# Epoch 3 training complete
# 3,0.14
# Epoch 4 training complete
# 4,0.14
# Epoch 5 training complete
# 5,0.14
# Epoch 6 training complete
# 6,0.14
# Epoch 7 training complete
# 7,0.14
# Epoch 8 training complete
# 8,0.14
# Epoch 9 training complete
# 9,0.14
# Epoch 10 training complete
# 10,0.14
# Epoch 11 training complete
# 11,0.14
# Epoch 12 training complete
# 12,0.14
# Epoch 13 training complete
# 13,0.14
# Epoch 14 training complete
# 14,0.14
# Epoch 15 training complete
# 15,0.14
# Epoch 16 training complete
# 16,0.14
# Epoch 17 training complete
# 17,0.14
# Epoch 18 training complete
# 18,0.14
# Epoch 19 training complete
# 19,0.14
# Epoch 20 training complete
# 20,0.14
# Epoch 21 training complete
# 21,0.14
# Epoch 22 training complete
# 22,0.17
# Epoch 23 training complete
# 23,0.21
# Epoch 24 training complete
# 24,0.22
# Epoch 25 training complete
# 25,0.22
# Epoch 26 training complete
# 26,0.22
# Epoch 27 training complete
# 27,0.22
# Epoch 28 training complete
# 28,0.22
# Epoch 29 training complete
# 29,0.22
# Epoch 30 training complete
# 30,0.22
# Epoch 31 training complete
# 31,0.22
# Epoch 32 training complete
# 32,0.22
# Epoch 33 training complete
# 33,0.22
# Epoch 34 training complete
# 34,0.22
# Epoch 35 training complete
# 35,0.14
# Epoch 36 training complete
# 36,0.22
# Epoch 37 training complete
# 37,0.22
# Epoch 38 training complete
# 38,0.21
# Epoch 39 training complete
# 39,0.14
# Epoch 40 training complete
# 40,0.14
# Epoch 41 training complete
# 41,0.14
# Epoch 42 training complete
# 42,0.14
# Epoch 43 training complete
# 43,0.14
# Epoch 44 training complete
# 44,0.14
# Epoch 45 training complete
# 45,0.14
# Epoch 46 training complete
# 46,0.14
# Epoch 47 training complete
# 47,0.14
# Epoch 48 training complete
# 48,0.14
# Epoch 49 training complete
# 49,0.14
# Epoch 50 training complete
# 50,0.14
# Epoch 51 training complete
# 51,0.14
# Epoch 52 training complete
# 52,0.14
# Epoch 53 training complete
# 53,0.14
# Epoch 54 training complete
# 54,0.18
# Epoch 55 training complete
# 55,0.21
# Epoch 56 training complete
# 56,0.22
# Epoch 57 training complete
# 57,0.22
# Epoch 58 training complete
# 58,0.22
# Epoch 59 training complete
# 59,0.17
# Epoch 60 training complete
# 60,0.08
# Epoch 61 training complete
# 61,0.14
# Epoch 62 training complete
# 62,0.17
# Epoch 63 training complete
# 63,0.22
# Epoch 64 training complete
# 64,0.16
# Epoch 65 training complete
# 65,0.16
# Epoch 66 training complete
# 66,0.19
# Epoch 67 training complete
# 67,0.22
# Epoch 68 training complete
# 68,0.22
# Epoch 69 training complete
# 69,0.22
# Epoch 70 training complete
# 70,0.22
# Epoch 71 training complete
# 71,0.22
# Epoch 72 training complete
# 72,0.22
# Epoch 73 training complete
# 73,0.22
# Epoch 74 training complete
# 74,0.22
# Epoch 75 training complete
# 75,0.23
# Epoch 76 training complete
# 76,0.14
# Epoch 77 training complete
# 77,0.18
# Epoch 78 training complete
# 78,0.22
# Epoch 79 training complete
# 79,0.22
# Epoch 80 training complete
# 80,0.23
# Epoch 81 training complete
# 81,0.22
# Epoch 82 training complete
# 82,0.22
# Epoch 83 training complete
# 83,0.22
# Epoch 84 training complete
# 84,0.23
# Epoch 85 training complete
# 85,0.22
# Epoch 86 training complete
# 86,0.22
# Epoch 87 training complete
# 87,0.22
# Epoch 88 training complete
# 88,0.11
# Epoch 89 training complete
# 89,0.14
# Epoch 90 training complete
# 90,0.19
# Epoch 91 training complete
# 91,0.22
# Epoch 92 training complete
# 92,0.22
# Epoch 93 training complete
# 93,0.23
# Epoch 94 training complete
# 94,0.23
# Epoch 95 training complete
# 95,0.24
# Epoch 96 training complete
# 96,0.24
# Epoch 97 training complete
# 97,0.26
# Epoch 98 training complete
# 98,0.26
# Epoch 99 training complete
# 99,0.32
# 4.603574752807617
# 0.08759606518113007
# 45
# [100, 100, 6.0] Dual Hidden Layers Plus Quadratic
# Epoch 0 training complete
# 0,0.11
# Epoch 1 training complete
# 1,0.08
# Epoch 2 training complete
# 2,0.08
# Epoch 3 training complete
# 3,0.08
# Epoch 4 training complete
# 4,0.08
# Epoch 5 training complete
# 5,0.08
# Epoch 6 training complete
# 6,0.08
# Epoch 7 training complete
# 7,0.08
# Epoch 8 training complete
# 8,0.08
# Epoch 9 training complete
# 9,0.08
# Epoch 10 training complete
# 10,0.08
# Epoch 11 training complete
# 11,0.08
# Epoch 12 training complete
# 12,0.21
# Epoch 13 training complete
# 13,0.22
# Epoch 14 training complete
# 14,0.22
# Epoch 15 training complete
# 15,0.22
# Epoch 16 training complete
# 16,0.22
# Epoch 17 training complete
# 17,0.22
# Epoch 18 training complete
# 18,0.22
# Epoch 19 training complete
# 19,0.22
# Epoch 20 training complete
# 20,0.22
# Epoch 21 training complete
# 21,0.22
# Epoch 22 training complete
# 22,0.22
# Epoch 23 training complete
# 23,0.22
# Epoch 24 training complete
# 24,0.22
# Epoch 25 training complete
# 25,0.22
# Epoch 26 training complete
# 26,0.22
# Epoch 27 training complete
# 27,0.22
# Epoch 28 training complete
# 28,0.22
# Epoch 29 training complete
# 29,0.22
# Epoch 30 training complete
# 30,0.22
# Epoch 31 training complete
# 31,0.22
# Epoch 32 training complete
# 32,0.22
# Epoch 33 training complete
# 33,0.22
# Epoch 34 training complete
# 34,0.22
# Epoch 35 training complete
# 35,0.22
# Epoch 36 training complete
# 36,0.22
# Epoch 37 training complete
# 37,0.22
# Epoch 38 training complete
# 38,0.22
# Epoch 39 training complete
# 39,0.22
# Epoch 40 training complete
# 40,0.22
# Epoch 41 training complete
# 41,0.22
# Epoch 42 training complete
# 42,0.22
# Epoch 43 training complete
# 43,0.22
# Epoch 44 training complete
# 44,0.22
# Epoch 45 training complete
# 45,0.22
# Epoch 46 training complete
# 46,0.23
# Epoch 47 training complete
# 47,0.25
# Epoch 48 training complete
# 48,0.25
# Epoch 49 training complete
# 49,0.25
# Epoch 50 training complete
# 50,0.26
# Epoch 51 training complete
# 51,0.29
# Epoch 52 training complete
# 52,0.32
# Epoch 53 training complete
# 53,0.33
# Epoch 54 training complete
# 54,0.34
# Epoch 55 training complete
# 55,0.34
# Epoch 56 training complete
# 56,0.35
# Epoch 57 training complete
# 57,0.36
# Epoch 58 training complete
# 58,0.36
# Epoch 59 training complete
# 59,0.36
# Epoch 60 training complete
# 60,0.38
# Epoch 61 training complete
# 61,0.41
# Epoch 62 training complete
# 62,0.41
# Epoch 63 training complete
# 63,0.41
# Epoch 64 training complete
# 64,0.42
# Epoch 65 training complete
# 65,0.43
# Epoch 66 training complete
# 66,0.44
# Epoch 67 training complete
# 67,0.45
# Epoch 68 training complete
# 68,0.45
# Epoch 69 training complete
# 69,0.47
# Epoch 70 training complete
# 70,0.48
# Epoch 71 training complete
# 71,0.48
# Epoch 72 training complete
# 72,0.48
# Epoch 73 training complete
# 73,0.5
# Epoch 74 training complete
# 74,0.52
# Epoch 75 training complete
# 75,0.51
# Epoch 76 training complete
# 76,0.52
# Epoch 77 training complete
# 77,0.5
# Epoch 78 training complete
# 78,0.5
# Epoch 79 training complete
# 79,0.51
# Epoch 80 training complete
# 80,0.54
# Epoch 81 training complete
# 81,0.55
# Epoch 82 training complete
# 82,0.56
# Epoch 83 training complete
# 83,0.56
# Epoch 84 training complete
# 84,0.56
# Epoch 85 training complete
# 85,0.57
# Epoch 86 training complete
# 86,0.56
# Epoch 87 training complete
# 87,0.56
# Epoch 88 training complete
# 88,0.56
# Epoch 89 training complete
# 89,0.57
# Epoch 90 training complete
# 90,0.57
# Epoch 91 training complete
# 91,0.57
# Epoch 92 training complete
# 92,0.57
# Epoch 93 training complete
# 93,0.58
# Epoch 94 training complete
# 94,0.58
# Epoch 95 training complete
# 95,0.58
# Epoch 96 training complete
# 96,0.58
# Epoch 97 training complete
# 97,0.58
# Epoch 98 training complete
# 98,0.58
# Epoch 99 training complete
# 99,0.58
# 7.619784116744995
# 0.1811822624376421
# 63

# %%
import matplotlib.pyplot as plt

# pre-process
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []
for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
    training_timesSingle.append(tt1)
    training_timesSingle.append(tt2)
for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
    training_timesDouble.append(tt1)
    training_timesDouble.append(tt2)

# accurate?
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []
for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
    accuraciesSingle.append(acc1[1][-1])
    accuraciesSingle.append(acc2[1][-1])
for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
    accuraciesDouble.append(acc1[1][-1])
    accuraciesDouble.append(acc2[1][-1])

# tags
labelsSingle = []
labelsDouble = []
for config in configs:
    labelsSingle.append(f"{config}-cross-784-15-10")
    labelsSingle.append(f"{config}-quad-784-15-10")
    labelsDouble.append(f"{config}-cross-784-30-15-10")
    labelsDouble.append(f"{config}-quad-784-30-15-10")

fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsSingle, accuraciesSingle)
plt.show()
fig, ax = plt.subplots(figsize=(50,10))
ax.plot(labelsDouble, training_timesDouble)
plt.show()

# %%
# complete
label_learningrate = []
tt_learningrate = []
acc_learningrate = []
for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i])
    tt_learningrate.append(training_timesSingle[2*i]) 
    acc_learningrate.append(accuraciesSingle[2*i]) 
    
print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
# Out:
# ['[30, 10, 0.1]-cross-784-15-10', '[30, 10, 0.5]-cross-784-15-10', '[30, 10, 1.0]-cross-784-15-10', '[30, 10, 3.0]-cross-784-15-10', '[30, 10, 5.0]-cross-784-15-10', '[30, 10, 6.0]-cross-784-15-10']
# [0.7202460765838623, 1.258875846862793, 0.7157764434814453, 0.7977240085601807, 0.7974615097045898, 0.751136302947998]
# [71, 69, 71, 66, 63, 34]
# <function matplotlib.pyplot.show(close=None, block=None)>
